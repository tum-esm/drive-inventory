# %% [markdown]
# # Download and process BAST traffic count data
# Source: https://www.bast.de/BASt_2017/DE/Verkehrstechnik/Fachthemen/v2-verkehrszaehlung/zaehl_node.html

# %%
import os
import requests

import geopandas as gpd
import numpy as np
import pandas as pd

from zipfile import ZipFile
from bs4 import BeautifulSoup
import data_paths as data_paths

# %% [markdown]
# ### Functions for download
# Functions for download and unzip BAST hourly data

# %%
#actual downloading -> Author: Johannes Gensheimer
def DownloadURL(url, save_path):
    #function from: https://stackoverflow.com/questions/9419162/download-returned-zip-file-from-url/14260592
    
    chunk_size=128
    r = requests.get(url, stream=True)
    with open(save_path, 'wb') as fd:
        for chunk in r.iter_content(chunk_size=chunk_size):
            fd.write(chunk)

#call download and unzip
def DownloadHourData_BAST(CounterNumber, year, FolderSave):

    BAST_Link = 'https://www.bast.de/videos/' + str(year) + '/zst' + str(CounterNumber) + '.zip'
    FileName = FolderSave + 'zst' + str(CounterNumber) + '_' + str(year) + '.zip'
    #download zip
    DownloadURL(BAST_Link, FileName)
    
    #unzip file if downloading was successfull
    try:
        zf = ZipFile(FileName, 'r')
        zf.extractall(FolderSave)
        zf.close()
        #remove zip file
        os.system('rm ' + FileName)
        return True
    except:
        print('Error while unzipping file: ' + FileName)
        return False

def DownloadRawData_BAST(year, FolderSave, link):
    FileName = FolderSave + 'DZ_' + str(year) + '_Rohdaten.zip'
    #download zip
    DownloadURL(link, FileName)
    
    #unzip file if downloading was successfull
    try:
        zf = ZipFile(FileName, 'r')
        zf.extractall(FolderSave)
        zf.close()
        #remove zip file
        os.system('rm ' + FileName)
        #return True
    except:
        print('Error while unzipping file: ' + FileName)
        return False
    
    #unzip next level of zip files (for each month)
    for month in range(1, 13):
        FileName = FolderSave + 'DZ_' + str(year) + '_' + str(month).zfill(2) + '_Rohdaten.zip'
        try:
            zf = ZipFile(FileName, 'r')
            zf.extractall(FolderSave)
            zf.close()
            #remove zip file
            os.system('rm ' + FileName)
        except:
            print('Error while unzipping file: ' + FileName)
    return True

# %% [markdown]
# ### Function to process download request
# DZ_Nr_unique: Number of counting stations <br>
# years: years that should be downloaded <br>
# path: path to temp directory where the downloaded data is temporary stored <br>
# keepOrigData: Bool if downloaded raw data should be deleted: True: not deleted, False: deleted <br>

# %%
def Process(DZ_Nr_unique, years, path, keepOrigData):

    #sort years array ascending
    years.sort()
    print(years)
    
    #create temporary directory
    if not os.path.exists(path):
        os.system('mkdir ' + path)

    #total number of counting stations that should be processed
    total_count = len(DZ_Nr_unique)

    #some prints
    print('All counter stations: ', DZ_Nr_unique)
    print('In total # = ', total_count)
    count = 1
    
    # empty dataframe for all data
    df_all = pd.DataFrame()
    
    #loop over all counting stations
    for nr in range(0,len(DZ_Nr_unique)):
        
        DZ_Nr = DZ_Nr_unique[nr]
        print('Processing ' , count, ' of ', total_count)
        count = count + 1
        
        #loop over years
        for year in years:
            
            #filename in temp dir
            f = 'zst' + str(DZ_Nr) + '_' + str(year) + '.csv'
            try:
                #download data
                DownloadHourData_BAST(DZ_Nr, year, path) # if download was successfull
                #read data
                df = pd.read_csv(path+f, delimiter=';')
                df_all = pd.concat([df_all, df], axis = 0)
                    
                #remove downloaded file if keepOrigData not True
                if not keepOrigData:
                    os.system('rm ' + path + f)
            except Exception as e:
                print("Could not download data for:"+str(DZ_Nr_unique[nr])+"/"+str(year))

    return df_all

def Process_raw(years, temp_path):
    #Remove years for which data is already available in the raw data folder
    for year in years:
        for month in range(1, 13):
            if not os.path.exists(temp_path + 'DZ_' + str(year) + '_' + str(month).zfill(2) + '_Rohdaten'):
                print('Data for year ' + str(year) + ' and month ' + str(month).zfill(2) + 'Does not exist')
                break
        years.remove(year)
    print('Years for which data will be downloaded: ', years)
    if years == []:
        print('No data needs to be downloaded. Returning.')
        return

    #Find all links to zip files for the specified years on the BAST website
    BAST_Link = 'https://www.bast.de/DE/Publikationen/Daten/Verkehrstechnik/DZ.html'
    response = requests.get(BAST_Link)
    soup = BeautifulSoup(response.text, 'html.parser')
    links = soup.find_all('a', href=lambda x: x and '.zip' in x and any(str(v) in x for v in years))

    for tag in links:
        link = tag.get('href', None)
        if link is not None:
            matched = [v for v in years if str(v) in link].pop()
            print(matched)
            DownloadRawData_BAST(matched, temp_path, link) # download and unzip raw data for the specified year
            print(link)

# %%
def delete_unused_locations(location_list, path):
    locations = ['BY' + str(location) for location in location_list]
    print(locations)
    # print(f"Deleting data of unused locations")
    for folder in os.listdir(path):
        if folder == '.DS_Store': continue
        new_path = os.path.join(path, folder)
        for file in os.listdir(new_path):
            temp_path = os.path.join(new_path, file)
            #print(os.listdir(temp_path))
            print(temp_path)
            print(os.path.isfile(temp_path))
            print("test")
            if os.path.isfile(temp_path) and not (str(file[:6]) in locations):
                print("delete")
                os.system('rm ' + temp_path)

# %%
def extract_append_raw_data(df_old, path, newFile='BAST_CountingStations_daily_new.csv'):
     
    for folder in os.listdir(path):
        if folder == '.DS_Store': continue
        print(f"Processing {folder}")
        new_path = os.path.join(path, folder + '/')
        for file in os.listdir(new_path):

            # Handle header rows individually, due to different number of elements
            df_header1 = pd.read_csv(new_path + file, encoding= 'unicode_escape', nrows=1, header=None, sep=r'\s+')
            df_header2 = pd.read_csv(new_path + file, encoding= 'unicode_escape', nrows=1, header=None, sep=r'\s+', skiprows=1)
            df_header3 = pd.read_csv(new_path + file, encoding= 'unicode_escape', nrows=1, header=None, sep=r'\s+', skiprows=2)

            # Copy Dataframe Schema
            df_new = pd.DataFrame().reindex_like(df_old).dropna()
            df_body = pd.read_csv(new_path + file, encoding= 'unicode_escape', skiprows=3, header=None,  sep=r'\s+')   
            
            # Drop faulty line (necessary because of measurements in march for some reason)
            df_body = df_body.drop(df_body[df_body[0].astype(str).str.contains('i', regex=False)].index)

        # Extract data from header
            df_new['Datum'] = df_body[0]
            df_new['Stunde'] = df_body[1].str.split(":").str[0].astype(int)
            df_new['KFZ_R1'] = df_body[2]
            df_new['Wotag'] = pd.to_datetime(df_new['Datum'].astype(str), format='%y%m%d').dt.weekday
            df_new['Wotag'] += 1 # dt.weekday specifies Monday=0 .. Sunday=6

            # Fill NaN's with 0
            df_new = df_new.fillna(0)

            # Extract necessary information
            df_new = df_new.assign(TKNR=df_header1.iloc[0, 0][1:5])
            df_new = df_new.assign(Zst = df_header1.iloc[0, 0][5:9])
            df_new = df_new.assign(Land = df_header1.iloc[0, 1])
            df_new = df_new.assign(Strklas = df_header1.iloc[0, 2])
            df_new = df_new.assign(Strnum = df_header1.iloc[0, 3])
            df_new = df_new.assign(Fahrtzw = 'n')

            # number of lanes in each direction
            lanes_per_direction = [int(df_header2.iloc[0, 0][1:]), int(df_header2.iloc[0, 1])]
            offset_date_time = 2
            offset_kfz_sv = 2 * (lanes_per_direction[0] + lanes_per_direction[1])

            # For some reason 1 station is different than all the other stations..
            if 'BY9223' in file:
                column = 'KFZ_R'

                for direction in range(2): # code only works for 2 directions
                    # KFZ and LKW (SV)
                    count_name = column + str(direction + 1)
                    check_name = 'K_' + column + str(direction + 1)
                    df_temp_count = df_body.iloc[:][offset_date_time + (direction * lanes_per_direction[0])].str.strip().str[:-1].astype(int)
                    df_temp_check = df_body.iloc[:][offset_date_time + (direction * lanes_per_direction[0])].str.strip().str[-1:]
                    for lane in range(1, lanes_per_direction[direction]):
                        df_temp_count += df_body.iloc[:][offset_date_time + (direction * lanes_per_direction[0]) + lane].str.strip().str[:-1].astype(int)

                    df_new[count_name] = df_temp_count
                    df_new[check_name] = df_temp_check
            else: 

                columns_kfz_lkw = ['KFZ_R', 'Lkw_R']
                columns_rest = ['Mot_R', 'Pkw_R', 'Lfw_R', 'PmA_R', 'Bus_R',
                                'LoA_R', 'Lzg_R', 'Sat_R', 'Son_R'] # attention, Lzg = LmA + Sat
                columns_calc = ['PLZ_R', 'Lzg_R'] # Lzg = LmA + Sat, PLZ = Mot + Pkw + Lfw

                for direction in range(2):
                    # KFZ and LKW (SV)
                    for idx, column in enumerate(columns_kfz_lkw):
                        count_name = column + str(direction + 1)
                        check_name = 'K_' + column + str(direction + 1)
                        df_temp_count = df_body.iloc[:][offset_date_time + idx + (direction * 2 * lanes_per_direction[0])].str.strip().str[:-1].astype(int)
                        df_temp_check = df_body.iloc[:][offset_date_time + idx + (direction * 2 * lanes_per_direction[0])].str.strip().str[-1:]
                        for lane in range(1, lanes_per_direction[direction]):
                            df_temp_count += df_body.iloc[:][offset_date_time + idx + (direction * 2 * lanes_per_direction[0]) + (2 * lane)].str.strip().str[:-1].astype(int)

                        df_new[count_name] = df_temp_count
                        df_new[check_name] = df_temp_check
                    # Other classes
                    for idx, column in enumerate(columns_rest):
                        count_name = column + str(direction + 1)
                        check_name = 'K_' + column + str(direction + 1)
                        df_temp_count = df_body.iloc[:][offset_date_time + offset_kfz_sv + idx + (direction * 9 * lanes_per_direction[0])].str.strip().str[:-1].astype(int)
                        df_temp_check = df_body.iloc[:][offset_date_time + offset_kfz_sv + idx + (direction * 9 * lanes_per_direction[0])].str.strip().str[-1:]
                        for lane in range(1, lanes_per_direction[direction]):
                            df_temp_count += df_body.iloc[:][offset_date_time + offset_kfz_sv + idx + (direction * 9 * lanes_per_direction[0]) + (9 * lane)].str.strip().str[:-1].astype(int)
                        df_new[count_name] = df_temp_count
                        df_new[check_name] = df_temp_check

                    # Lzg = LmA + Sat
                    df_new['Lzg_R' + str(direction + 1)] += df_new['Sat_R' + str(direction + 1)]
                    # PLZ = Mot + Pkw + Lfw
                    df_new['PLZ_R' + str(direction + 1)] = df_new['Mot_R' + str(direction + 1)] + df_new['Pkw_R' + str(direction + 1)] + df_new['Lfw_R' + str(direction + 1)]
                    df_new['K_PLZ_R' + str(direction + 1)] = df_new['K_Mot_R' + str(direction + 1)] # Not sure how to handle this  
            df_old = pd.concat([df_old, df_new])
        print(f"Completed {folder}")
    print(f"Writing to file {newFile}")
    df_old.to_csv(newFile)
    return df_old

# %% [markdown]
# # Run the functions

# %%
bast_locations = gpd.read_file(data_paths.BAST_LOCATIONS_FILE)
station_ids = np.array(bast_locations['MST_ID'].unique()) # counting station number

years = np.array([2023]) # years of interst

# download processed datasets from BAST homepage
df_daily = Process(station_ids, years, path='temp/', keepOrigData=False)
df_daily.to_csv(data_paths.BAST_COUNTING_PATH + 'BAST_CountingStations_daily_until2022.csv')
# Out:
# [2023]
# All counter stations:  [9140 9141 9772 9773 9082 9003 9083 9115 9066 9063 9242 9064 9217 9006
#  9987 9986 9985 9151 9043 9222 9106 9207 9775 9774 9215 9212 9213 9220
#  9219 9218 9211 9155 9228 9244 9229 9221 9830 9820 9810 9320 9102 9988]
# In total # =  42
# Processing  1  of  42
# Processing  2  of  42
# Processing  3  of  42
# Processing  4  of  42
# Error while unzipping file: temp/zst9773_2023.zip
# Could not download data for:9773/2023
# Processing  5  of  42
# Processing  6  of  42
# Processing  7  of  42
# Processing  8  of  42
# Error while unzipping file: temp/zst9115_2023.zip
# Could not download data for:9115/2023
# Processing  9  of  42
# Processing  10  of  42
# Processing  11  of  42
# Processing  12  of  42
# Processing  13  of  42
# Processing  14  of  42
# Processing  15  of  42
# Processing  16  of  42
# Error while unzipping file: temp/zst9986_2023.zip
# Could not download data for:9986/2023
# Processing  17  of  42
# Error while unzipping file: temp/zst9985_2023.zip
# Could not download data for:9985/2023
# Processing  18  of  42
# Processing  19  of  42
# Processing  20  of  42
# Processing  21  of  42
# Processing  22  of  42
# Processing  23  of  42
# Processing  24  of  42
# Processing  25  of  42
# Error while unzipping file: temp/zst9215_2023.zip
# Could not download data for:9215/2023
# Processing  26  of  42
# Error while unzipping file: temp/zst9212_2023.zip
# Could not download data for:9212/2023
# Processing  27  of  42
# Processing  28  of  42
# Processing  29  of  42
# Processing  30  of  42
# Error while unzipping file: temp/zst9218_2023.zip
# Could not download data for:9218/2023
# Processing  31  of  42
# Error while unzipping file: temp/zst9211_2023.zip
# Could not download data for:9211/2023
# Processing  32  of  42
# Processing  33  of  42
# Error while unzipping file: temp/zst9228_2023.zip
# Could not download data for:9228/2023
# Processing  34  of  42
# Processing  35  of  42
# Processing  36  of  42
# Processing  37  of  42
# Processing  38  of  42
# Processing  39  of  42
# Processing  40  of  42
# Processing  41  of  42
# Error while unzipping file: temp/zst9102_2023.zip
# Could not download data for:9102/2023
# Processing  42  of  42

# %%
# Raw data
print(station_ids)
# create temporary directory to save raw data for the raw data download  
temp_path = data_paths.DATA_PATH + 'temp_raw/'
if not os.path.exists(temp_path):
    os.makedirs(temp_path)
# Download raw data from BAST can be performed manually from the follwowing link and unzipped into the temp_raw/ folder
# URL = 'https://www.bast.de/DE/Publikationen/Daten/Verkehrstechnik/DZ.html'
# the downloaded zip file contains zip files for each month
years_raw = [2024] # select the years for which raw data should be downloaded
Process_raw(years_raw, temp_path) # get links for raw data download for the specified years

# Remove stations not in DZ_Nr_arr
delete_unused_locations(station_ids, temp_path)
# extract and append raw data to previous df
extract_append_raw_data(df_daily, temp_path, data_paths.BAST_COUNTING_PATH + 'BAST_CountingStations_daily_until2024.csv')
# Out:
# [9140 9141 9772 9773 9082 9003 9083 9115 9066 9063 9242 9064 9217 9006
#  9987 9986 9985 9151 9043 9222 9106 9207 9775 9774 9215 9212 9213 9220
#  9219 9218 9211 9155 9228 9244 9229 9221 9830 9820 9810 9320 9102 9988]
# Years for which data will be downloaded:  []
# No data needs to be downloaded. Returning.
# ['BY9140', 'BY9141', 'BY9772', 'BY9773', 'BY9082', 'BY9003', 'BY9083', 'BY9115', 'BY9066', 'BY9063', 'BY9242', 'BY9064', 'BY9217', 'BY9006', 'BY9987', 'BY9986', 'BY9985', 'BY9151', 'BY9043', 'BY9222', 'BY9106', 'BY9207', 'BY9775', 'BY9774', 'BY9215', 'BY9212', 'BY9213', 'BY9220', 'BY9219', 'BY9218', 'BY9211', 'BY9155', 'BY9228', 'BY9244', 'BY9229', 'BY9221', 'BY9830', 'BY9820', 'BY9810', 'BY9320', 'BY9102', 'BY9988']
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9151.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9063.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9213.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9220.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9082.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9820.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9775.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9988.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9830.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9102.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9155.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9083.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9218.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9773.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9043.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9219.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9229.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9064.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9772.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9006.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9212.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9222.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9140.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9066.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9242.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9320.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9211.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9207.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9985.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9221.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9217.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9115.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9003.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9244.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9215.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9987.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9106.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9810.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9228.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9986.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9141.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_08_Rohdaten/BY9774.248
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9141.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9215.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9772.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9242.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9219.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9155.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9102.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9830.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9810.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9106.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9986.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9211.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9082.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9151.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9774.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9222.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9988.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9244.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9213.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9217.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9083.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9064.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9003.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9820.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9773.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9985.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9006.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9212.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9043.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9775.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9228.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9218.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9115.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9229.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9207.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9220.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9320.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9140.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9221.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9987.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9063.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_09_Rohdaten/BY9066.249
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9221.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9064.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9219.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9772.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9106.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9006.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9773.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9775.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9320.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9140.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9211.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9810.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9220.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9830.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9218.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9207.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9151.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9242.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9987.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9003.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9212.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9082.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9986.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9213.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9066.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9063.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9141.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9043.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9988.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9229.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9820.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9222.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9215.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9774.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9228.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9244.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9115.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9985.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9102.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9083.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9217.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_06_Rohdaten/BY9155.246
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9211.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9217.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9320.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9773.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9003.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9115.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9830.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9083.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9820.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9215.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9986.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9064.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9222.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9140.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9985.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9244.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9141.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9006.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9772.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9155.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9207.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9082.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9229.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9774.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9221.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9775.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9219.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9066.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9213.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9063.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9218.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9810.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9102.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9228.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9987.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9043.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9151.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9988.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9220.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9242.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9106.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_05_Rohdaten/BY9212.245
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9244.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9820.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9218.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9772.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9155.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9221.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9229.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9063.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9810.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9140.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9320.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9220.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9242.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9211.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9986.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9775.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9773.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9217.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9985.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9988.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9102.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9774.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9082.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9006.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9987.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9151.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9043.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9207.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9213.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9228.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9219.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9106.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9141.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9064.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9115.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9212.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9222.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9830.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9003.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9215.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9066.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_07_Rohdaten/BY9083.247
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9986.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9229.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9218.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9242.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9003.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9106.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9213.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9211.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9810.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9215.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9985.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9220.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9773.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9155.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9320.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9988.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9774.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9222.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9772.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9219.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9221.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9083.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9006.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9775.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9228.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9212.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9140.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9064.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9244.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9987.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9063.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9141.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9830.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9102.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9820.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9217.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9207.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9151.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9066.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9115.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9043.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_10_Rohdaten/BY9082.24a
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9221.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9244.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9082.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9830.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9066.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9222.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9775.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9151.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9064.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9242.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9985.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9006.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9218.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9140.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9820.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9211.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9215.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9063.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9988.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9141.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9229.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9219.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9212.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9774.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9987.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9106.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9772.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9217.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9083.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9986.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9213.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9115.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9003.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9102.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9155.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9043.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9320.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9773.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9810.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9228.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9207.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_11_Rohdaten/BY9220.24b
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9229.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9066.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9219.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9064.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9228.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9986.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9211.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9218.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9220.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9207.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9320.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9244.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9213.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9775.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9151.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9215.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9141.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9115.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9221.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9140.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9988.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9102.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9043.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9212.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9063.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9106.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9810.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9083.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9222.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9830.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9985.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9773.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9987.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9772.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9820.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9217.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9242.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9155.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9774.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9003.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9006.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_01_Rohdaten/BY9082.241
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9106.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9320.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9810.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9140.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9985.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9220.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9773.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9242.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9141.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9988.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9102.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9151.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9115.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9207.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9155.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9043.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9003.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9006.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9219.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9244.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9221.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9211.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9774.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9064.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9082.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9987.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9229.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9820.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9986.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9222.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9063.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9212.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9772.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9830.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9775.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9215.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9217.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9066.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9083.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9213.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9228.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_04_Rohdaten/BY9218.244
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9320.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9218.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9082.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9141.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9102.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9228.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9242.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9773.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9115.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9064.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9043.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9155.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9774.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9229.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9772.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9220.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9211.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9219.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9212.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9244.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9820.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9217.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9221.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9775.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9083.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9006.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9988.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9003.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9985.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9063.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9207.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9830.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9213.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9106.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9151.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9066.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9986.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9140.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9987.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9215.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9810.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_03_Rohdaten/BY9222.243
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9217.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9215.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9219.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9141.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9775.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9774.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9043.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9218.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9988.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9006.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9222.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9102.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9151.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9207.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9063.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9244.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9220.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9064.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9221.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9213.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9155.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9985.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9987.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9773.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9140.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9211.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9228.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9066.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9830.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9242.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9810.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9986.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9003.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9083.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9772.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9115.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9320.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9106.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9229.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9212.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9082.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_02_Rohdaten/BY9820.242
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9207.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9221.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9218.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9772.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9213.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9006.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9228.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9320.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9151.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9810.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9229.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9820.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9102.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9773.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9211.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9215.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9106.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9987.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9064.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9220.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9988.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9242.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9775.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9141.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9774.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9985.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9219.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9115.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9244.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9222.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9003.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9155.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9043.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9217.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9063.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9830.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9066.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9986.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9140.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9082.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9212.24c
# True
# test
# /home/quzibo/Documents/HiWI/drive-inventory/data/temp_raw/DZ_2024_12_Rohdaten/BY9083.24c
# True
# test
# Processing DZ_2024_08_Rohdaten
# Completed DZ_2024_08_Rohdaten
# Processing DZ_2024_09_Rohdaten
# Completed DZ_2024_09_Rohdaten
# Processing DZ_2024_06_Rohdaten
# Completed DZ_2024_06_Rohdaten
# Processing DZ_2024_05_Rohdaten
# Completed DZ_2024_05_Rohdaten
# Processing DZ_2024_07_Rohdaten
# Completed DZ_2024_07_Rohdaten
# Processing DZ_2024_10_Rohdaten
# Completed DZ_2024_10_Rohdaten
# Processing DZ_2024_11_Rohdaten
# Completed DZ_2024_11_Rohdaten
# Processing DZ_2024_01_Rohdaten
# Completed DZ_2024_01_Rohdaten
# Processing DZ_2024_04_Rohdaten
# Completed DZ_2024_04_Rohdaten
# Processing DZ_2024_03_Rohdaten
# Completed DZ_2024_03_Rohdaten
# Processing DZ_2024_02_Rohdaten
# Completed DZ_2024_02_Rohdaten
# Processing DZ_2024_12_Rohdaten
# Completed DZ_2024_12_Rohdaten
# Writing to file /home/quzibo/Documents/HiWI/drive-inventory/data/restricted_input/counting_data/bast/BAST_CountingStations_daily_until2024.csv
#      TKNR   Zst  Land Strklas  Strnum   Datum  Wotag Fahrtzw  Stunde  KFZ_R1  \
# 0    7834  9140     9       A       8  230101      7       s       1      88
# 1    7834  9140     9       A       8  230101      7       s       2     259
# 2    7834  9140     9       A       8  230101      7       s       3     268
# 3    7834  9140     9       A       8  230101      7       s       4     160
# 4    7834  9140     9       A       8  230101      7       s       5      96
# ..    ...   ...   ...     ...     ...     ...    ...     ...     ...     ...
# 739  7935  9083     9       A       8  241231      2       n      20     560
# 740  7935  9083     9       A       8  241231      2       n      21     353
# 741  7935  9083     9       A       8  241231      2       n      22     288
# 742  7935  9083     9       A       8  241231      2       n      23     293
# 743  7935  9083     9       A       8  241231      2       n      24     183
#
#      ... Bus_R2  K_Bus_R2 LoA_R2  K_LoA_R2 Lzg_R2  K_Lzg_R2 Sat_R2  K_Sat_R2  \
# 0    ...      0         a      0         a      0         a      0         a
# 1    ...      0         a      0         a      0         a      0         a
# 2    ...      0         a      0         a      0         a      0         a
# 3    ...      0         a      0         a      0         a      0         a
# 4    ...      0         a      0         a      0         a      0         a
# ..   ...    ...       ...    ...       ...    ...       ...    ...       ...
# 739  ...      0         -      1         -      2         -      1         -
# 740  ...      0         -      0         -      1         -      1         -
# 741  ...      1         -      0         -      1         -      1         -
# 742  ...      1         -      0         -      1         -      1         -
# 743  ...      0         -      1         -      0         -      0         -
#
#     Son_R2  K_Son_R2
# 0        0         a
# 1        0         a
# 2        0         a
# 3        0         a
# 4        0         a
# ..     ...       ...
# 739      0         -
# 740      0         -
# 741      0         -
# 742      0         -
# 743      0         -
#
# [649206 rows x 57 columns]

# %%
df_test = pd.read_csv(data_paths.BAST_COUNTING_PATH + 'BAST_CountingStations_daily_until2024.csv', index_col=0).sort_values('Datum')
df_test['Datum'].max()
# Out:
# np.int64(241231)

# %%
#df_test = pd.read_csv('BAST_CountingStations_daily_until2022.csv', index_col=0)

df_daily.tail()
# Out:
#       TKNR   Zst  Land Strklas  Strnum   Datum  Wotag Fahrtzw  Stunde  KFZ_R1  \
# 8755  7734  9988     9       B     471  231231      7       s      20     192
# 8756  7734  9988     9       B     471  231231      7       s      21     145
# 8757  7734  9988     9       B     471  231231      7       s      22     108
# 8758  7734  9988     9       B     471  231231      7       s      23     101
# 8759  7734  9988     9       B     471  231231      7       s      24      90
#
#       ... Bus_R2  K_Bus_R2 LoA_R2  K_LoA_R2 Lzg_R2  K_Lzg_R2 Sat_R2  K_Sat_R2  \
# 8755  ...      0         -      1         -      0         -      0         -
# 8756  ...      0         -      2         -      0         -      0         -
# 8757  ...      0         -      1         -      0         -      0         -
# 8758  ...      1         -      0         -      0         -      0         -
# 8759  ...      0         -      1         -      2         -      2         -
#
#      Son_R2  K_Son_R2
# 8755      0         -
# 8756      0         -
# 8757      0         -
# 8758      0         -
# 8759      0         -
#
# [5 rows x 57 columns]
