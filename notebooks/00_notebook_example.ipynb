# %% [markdown]
# *Technical University of Munich<br>
# Professorship of Environmental Sensing and Modeling<br><br>*
# **Author:**  Daniel Kühbacher<br>
# **Date:**  26.10.2023
#
# ---
#
# # Example notebook
#
# <!--Notebook description and usage information-->
# This notebook shows how Jupyter notebooks are intended to be used within the project and to check if your package installations worked well.

# %%
import sys

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
import seaborn as sns

from bokeh.plotting import figure, show
from bokeh.io import output_notebook
output_notebook()

# import custom modules
sys.path.append('../utils')
import calender
import data_paths
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d80c9d42-2aff-4703-839a-1f41d068ffbf">Loading BokehJS ...</span>
#     </div>

# %%
# example bokeh plot
x = np.random.random(size = 1000)
y = np.random.random(size = 1000)

# %%
p=figure()
p.circle(x,y)
show(p)
# Out:
#   <div id="e2a549a5-db77-4eb7-9666-b26e6b54a7c4" data-root-id="p1001" style="display: contents;"></div>

# %%
sns.scatterplot(x=x, y=y)
plt.show()

# %%
calender.fetch_calendar(date_is_index=False, year='2019')
# Out:
#           date  day_of_week  day_type       description  yeartime
# 0   2019-01-01            1         3           Neujahr         4
# 1   2019-01-02            2         5  Weihnachtsferien         4
# 2   2019-01-03            3         5  Weihnachtsferien         4
# 3   2019-01-04            4         5  Weihnachtsferien         4
# 4   2019-01-05            5         2               NaN         4
# ..         ...          ...       ...               ...       ...
# 360 2019-12-27            4         5  Weihnachtsferien         4
# 361 2019-12-28            5         2  Weihnachtsferien         4
# 362 2019-12-29            6         2  Weihnachtsferien         4
# 363 2019-12-30            0         5  Weihnachtsferien         4
# 364 2019-12-31            1         5  Weihnachtsferien         4
#
# [365 rows x 5 columns]
