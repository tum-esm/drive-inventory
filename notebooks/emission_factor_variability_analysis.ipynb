# %% [markdown]
# *Technical University of Munich<br>
# Professorship of Environmental Sensing and Modeling<br><br>*
# **Author:**  Daniel Kühbacher<br>
# **Date:**  12.3.2024
#
# ---
#
# # Emission Factor Variability Test
#
# <!--Notebook description and usage information-->

# %%
import sys
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import colors

import seaborn as sns

# import custom modules
sys.path.append('../utils')
import data_paths

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# # Import Emission Factor Tables

# %%
ef_austria = pd.read_excel(data_paths.EF_path + 'ef_eval/EFA_HOT_Vehcat_austria_main_cat_10deg.XLS')
ef_france = pd.read_excel(data_paths.EF_path + 'ef_eval/EFA_HOT_Vehcat_france_main_cat_10deg.XLS')
ef_germany = pd.read_excel(data_paths.EF_path + 'ef_eval/EFA_HOT_Vehcat_germany_main_cat_10deg.XLS')
ef_swiss = pd.read_excel(data_paths.EF_path + 'ef_eval/EFA_HOT_Vehcat_switzerland_main_cat_10deg.XLS')

ef_germany['country'] = 'Germany'
ef_austria['country'] = 'Austria'
ef_swiss['country'] = 'Switzerland'
ef_france['country'] = 'France'
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %% [markdown]
# # Calculate EF Variability
# In this analysis, the emission factors of different countries and years are combine and their spread investigated. This provides insight into the relative emission factor uncertainty induced by different vehicle fleets (age and composition).
#
#
# Ambient condition: 10°C </br>
# Road gradient: 0%

# %%
# combine emission factor tables
year_of_interest = 2019
year_variation = 2
country_of_interest = 'Germany'

column_name = f'{country_of_interest}_{year_of_interest}'

# combine emission factors
ef_table = pd.concat([ef_austria, ef_germany, ef_swiss, ef_france])
ef_table[['preamble', 'road_type', 'hbefa_speed', 'traffic_situation']] = ef_table.apply(\
    lambda row: row['TrafficSit'].split('/'),result_type="expand", axis =1)

# reduce to interesting years 
ef_table = ef_table[ef_table['Year'].isin(range(year_of_interest-year_variation,
                                                year_of_interest+year_variation))]

ef_grouped_stat = ef_table.groupby(['VehCat', 'Component', 'TrafficSit']).agg({'EFA_weighted':['min', 'max']})
ef_grouped_stat = ef_grouped_stat.droplevel(level = 0, axis = 1)
_ef_coi = ef_table.set_index(['VehCat', 'Component', 'TrafficSit'])
ef_coi = _ef_coi[(_ef_coi['country']== country_of_interest) & (_ef_coi['Year']== year_of_interest)]['EFA_weighted']

ef_grouped = pd.merge(ef_coi, ef_grouped_stat, left_index=True, right_index=True)
ef_grouped = ef_grouped.rename(columns={'EFA_weighted': column_name})

ef_grouped['rel_min'] = -((ef_grouped[column_name] - ef_grouped['min'])/ ef_grouped[column_name])
ef_grouped['rel_max'] = -((ef_grouped[column_name] - ef_grouped['max'])/ ef_grouped[column_name])

ef_grouped
# Out:
#                                               Germany_2019          min  \
# VehCat    Component TrafficSit
# pass. car CO        URB/MW-Nat./120/Freeflow      0.625343     0.294438
#                     URB/MW-Nat./120/Heavy         0.379163     0.186728
#                     URB/MW-Nat./120/Satur.        0.730747     0.313469
#                     URB/MW-Nat./120/St+Go         0.455270     0.243430
#                     URB/MW-Nat./120/St+Go2        0.779131     0.353643
# ...                                                    ...          ...
# HGV       CO2e      URB/Access/30/Freeflow      593.442017   577.521851
#                     URB/Access/30/Heavy         599.979126   583.584229
#                     URB/Access/30/Satur.        846.360779   823.380066
#                     URB/Access/30/St+Go        1225.227783  1191.404663
#                     URB/Access/30/St+Go2       1607.800903  1560.765137
#
#                                                       max   rel_min   rel_max
# VehCat    Component TrafficSit
# pass. car CO        URB/MW-Nat./120/Freeflow     0.676941 -0.529157  0.082512
#                     URB/MW-Nat./120/Heavy        0.404161 -0.507527  0.065930
#                     URB/MW-Nat./120/Satur.       0.791919 -0.571030  0.083712
#                     URB/MW-Nat./120/St+Go        0.507514 -0.465306  0.114753
#                     URB/MW-Nat./120/St+Go2       0.916881 -0.546106  0.176799
# ...                                                   ...       ...       ...
# HGV       CO2e      URB/Access/30/Freeflow     854.858643 -0.026827  0.440509
#                     URB/Access/30/Heavy        862.908997 -0.027326  0.438232
#                     URB/Access/30/Satur.      1227.321289 -0.027152  0.450116
#                     URB/Access/30/St+Go       1783.059082 -0.027606  0.455288
#                     URB/Access/30/St+Go2      2311.062256 -0.029255  0.437406
#
# [900 rows x 5 columns]

# %%
ef_test_result = ef_grouped.reset_index().groupby(['VehCat', 'Component'])[['rel_min', 'rel_max']].median().reset_index()
ef_test_result = ef_test_result.pivot(index='Component', columns =['VehCat'])
ef_test_result.to_csv(data_paths.EF_path + 'EF_sensitivity.csv')

# plot values in table
cm = sns.diverging_palette(5, 250, s = 75, as_cmap=True)
divnorm = colors.TwoSlopeNorm(vmin=ef_test_result.values.min(), vcenter=0, vmax=ef_test_result.values.max())
ef_test_result.style.background_gradient(cmap=cm, axis=None, vmin=0, vmax=1, gmap=ef_test_result.apply(divnorm)).format("{:.1%}")
# Out:
# <style type="text/css">
# #T_8fa6e_row0_col0 {
#   background-color: #e595a5;
#   color: #000000;
# }
# #T_8fa6e_row0_col1 {
#   background-color: #e69dab;
#   color: #000000;
# }
# #T_8fa6e_row0_col2 {
#   background-color: #e69ead;
#   color: #000000;
# }
# #T_8fa6e_row0_col3 {
#   background-color: #d84361;
#   color: #f1f1f1;
# }
# #T_8fa6e_row0_col4 {
#   background-color: #df6d84;
#   color: #f1f1f1;
# }
# #T_8fa6e_row0_col5, #T_8fa6e_row7_col5 {
#   background-color: #d0dae8;
#   color: #000000;
# }
# #T_8fa6e_row0_col6 {
#   background-color: #cdd9e7;
#   color: #000000;
# }
# #T_8fa6e_row0_col7 {
#   background-color: #cbd7e6;
#   color: #000000;
# }
# #T_8fa6e_row0_col8, #T_8fa6e_row2_col7, #T_8fa6e_row3_col8, #T_8fa6e_row6_col7 {
#   background-color: #e8ebf0;
#   color: #000000;
# }
# #T_8fa6e_row0_col9 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_8fa6e_row1_col0 {
#   background-color: #e6a1af;
#   color: #000000;
# }
# #T_8fa6e_row1_col1, #T_8fa6e_row2_col0 {
#   background-color: #ecc6ce;
#   color: #000000;
# }
# #T_8fa6e_row1_col2 {
#   background-color: #e48fa0;
#   color: #f1f1f1;
# }
# #T_8fa6e_row1_col3 {
#   background-color: #dd6179;
#   color: #f1f1f1;
# }
# #T_8fa6e_row1_col4 {
#   background-color: #edcdd3;
#   color: #000000;
# }
# #T_8fa6e_row1_col5 {
#   background-color: #bdcde2;
#   color: #000000;
# }
# #T_8fa6e_row1_col6, #T_8fa6e_row8_col5 {
#   background-color: #dce3ec;
#   color: #000000;
# }
# #T_8fa6e_row1_col7 {
#   background-color: #becee2;
#   color: #000000;
# }
# #T_8fa6e_row1_col8, #T_8fa6e_row3_col7, #T_8fa6e_row3_col9, #T_8fa6e_row4_col9, #T_8fa6e_row5_col7, #T_8fa6e_row5_col9 {
#   background-color: #eff0f2;
#   color: #000000;
# }
# #T_8fa6e_row1_col9 {
#   background-color: #edeef1;
#   color: #000000;
# }
# #T_8fa6e_row2_col1 {
#   background-color: #e0748a;
#   color: #f1f1f1;
# }
# #T_8fa6e_row2_col2 {
#   background-color: #e7a8b5;
#   color: #000000;
# }
# #T_8fa6e_row2_col3 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_8fa6e_row2_col4 {
#   background-color: #e28396;
#   color: #f1f1f1;
# }
# #T_8fa6e_row2_col5 {
#   background-color: #cfdae7;
#   color: #000000;
# }
# #T_8fa6e_row2_col6, #T_8fa6e_row3_col5, #T_8fa6e_row5_col5 {
#   background-color: #e2e7ee;
#   color: #000000;
# }
# #T_8fa6e_row2_col8, #T_8fa6e_row2_col9, #T_8fa6e_row4_col7 {
#   background-color: #eeeff2;
#   color: #000000;
# }
# #T_8fa6e_row3_col0, #T_8fa6e_row5_col0 {
#   background-color: #f2ebec;
#   color: #000000;
# }
# #T_8fa6e_row3_col1, #T_8fa6e_row5_col1 {
#   background-color: #eed2d7;
#   color: #000000;
# }
# #T_8fa6e_row3_col2, #T_8fa6e_row3_col4, #T_8fa6e_row4_col1, #T_8fa6e_row5_col2, #T_8fa6e_row5_col4 {
#   background-color: #eed4d9;
#   color: #000000;
# }
# #T_8fa6e_row3_col3, #T_8fa6e_row5_col3 {
#   background-color: #ecc9d0;
#   color: #000000;
# }
# #T_8fa6e_row3_col6, #T_8fa6e_row4_col6, #T_8fa6e_row5_col6 {
#   background-color: #f1f1f2;
#   color: #000000;
# }
# #T_8fa6e_row4_col0 {
#   background-color: #f2f1f1;
#   color: #000000;
# }
# #T_8fa6e_row4_col2, #T_8fa6e_row7_col0 {
#   background-color: #eed6db;
#   color: #000000;
# }
# #T_8fa6e_row4_col3, #T_8fa6e_row6_col4 {
#   background-color: #edcad1;
#   color: #000000;
# }
# #T_8fa6e_row4_col4 {
#   background-color: #f0dee2;
#   color: #000000;
# }
# #T_8fa6e_row4_col5 {
#   background-color: #e0e6ed;
#   color: #000000;
# }
# #T_8fa6e_row4_col8 {
#   background-color: #e6eaef;
#   color: #000000;
# }
# #T_8fa6e_row5_col8 {
#   background-color: #eaecf0;
#   color: #000000;
# }
# #T_8fa6e_row6_col0 {
#   background-color: #efdcdf;
#   color: #000000;
# }
# #T_8fa6e_row6_col1 {
#   background-color: #edd0d6;
#   color: #000000;
# }
# #T_8fa6e_row6_col2, #T_8fa6e_row7_col4 {
#   background-color: #e9b2bd;
#   color: #000000;
# }
# #T_8fa6e_row6_col3, #T_8fa6e_row7_col3 {
#   background-color: #e28497;
#   color: #f1f1f1;
# }
# #T_8fa6e_row6_col5 {
#   background-color: #dae1eb;
#   color: #000000;
# }
# #T_8fa6e_row6_col6 {
#   background-color: #dee4ec;
#   color: #000000;
# }
# #T_8fa6e_row6_col8, #T_8fa6e_row7_col8, #T_8fa6e_row8_col8 {
#   background-color: #ebedf1;
#   color: #000000;
# }
# #T_8fa6e_row6_col9 {
#   background-color: #b9cae0;
#   color: #000000;
# }
# #T_8fa6e_row7_col1 {
#   background-color: #edccd2;
#   color: #000000;
# }
# #T_8fa6e_row7_col2 {
#   background-color: #e7a7b4;
#   color: #000000;
# }
# #T_8fa6e_row7_col6 {
#   background-color: #e7eaef;
#   color: #000000;
# }
# #T_8fa6e_row7_col7 {
#   background-color: #e3e8ee;
#   color: #000000;
# }
# #T_8fa6e_row7_col9 {
#   background-color: #d4dde9;
#   color: #000000;
# }
# #T_8fa6e_row8_col0 {
#   background-color: #e9b1bc;
#   color: #000000;
# }
# #T_8fa6e_row8_col1 {
#   background-color: #e8aab6;
#   color: #000000;
# }
# #T_8fa6e_row8_col2 {
#   background-color: #e7a4b1;
#   color: #000000;
# }
# #T_8fa6e_row8_col3 {
#   background-color: #d8405e;
#   color: #f1f1f1;
# }
# #T_8fa6e_row8_col4 {
#   background-color: #e48e9f;
#   color: #f1f1f1;
# }
# #T_8fa6e_row8_col6, #T_8fa6e_row8_col7 {
#   background-color: #d3dce9;
#   color: #000000;
# }
# #T_8fa6e_row8_col9 {
#   background-color: #7ea1cd;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8fa6e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8fa6e_level0_col0" class="col_heading level0 col0" colspan="5">rel_min</th>
#       <th id="T_8fa6e_level0_col5" class="col_heading level0 col5" colspan="5">rel_max</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >VehCat</th>
#       <th id="T_8fa6e_level1_col0" class="col_heading level1 col0" >HGV</th>
#       <th id="T_8fa6e_level1_col1" class="col_heading level1 col1" >LCV</th>
#       <th id="T_8fa6e_level1_col2" class="col_heading level1 col2" >coach</th>
#       <th id="T_8fa6e_level1_col3" class="col_heading level1 col3" >motorcycle</th>
#       <th id="T_8fa6e_level1_col4" class="col_heading level1 col4" >pass. car</th>
#       <th id="T_8fa6e_level1_col5" class="col_heading level1 col5" >HGV</th>
#       <th id="T_8fa6e_level1_col6" class="col_heading level1 col6" >LCV</th>
#       <th id="T_8fa6e_level1_col7" class="col_heading level1 col7" >coach</th>
#       <th id="T_8fa6e_level1_col8" class="col_heading level1 col8" >motorcycle</th>
#       <th id="T_8fa6e_level1_col9" class="col_heading level1 col9" >pass. car</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Component</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8fa6e_level0_row0" class="row_heading level0 row0" >BC (exhaust)</th>
#       <td id="T_8fa6e_row0_col0" class="data row0 col0" >-41.2%</td>
#       <td id="T_8fa6e_row0_col1" class="data row0 col1" >-38.2%</td>
#       <td id="T_8fa6e_row0_col2" class="data row0 col2" >-37.4%</td>
#       <td id="T_8fa6e_row0_col3" class="data row0 col3" >-77.8%</td>
#       <td id="T_8fa6e_row0_col4" class="data row0 col4" >-58.7%</td>
#       <td id="T_8fa6e_row0_col5" class="data row0 col5" >93.8%</td>
#       <td id="T_8fa6e_row0_col6" class="data row0 col6" >99.6%</td>
#       <td id="T_8fa6e_row0_col7" class="data row0 col7" >107.6%</td>
#       <td id="T_8fa6e_row0_col8" class="data row0 col8" >25.8%</td>
#       <td id="T_8fa6e_row0_col9" class="data row0 col9" >481.6%</td>
#     </tr>
#     <tr>
#       <th id="T_8fa6e_level0_row1" class="row_heading level0 row1" >CH4</th>
#       <td id="T_8fa6e_row1_col0" class="data row1 col0" >-35.9%</td>
#       <td id="T_8fa6e_row1_col1" class="data row1 col1" >-19.5%</td>
#       <td id="T_8fa6e_row1_col2" class="data row1 col2" >-43.9%</td>
#       <td id="T_8fa6e_row1_col3" class="data row1 col3" >-65.0%</td>
#       <td id="T_8fa6e_row1_col4" class="data row1 col4" >-16.5%</td>
#       <td id="T_8fa6e_row1_col5" class="data row1 col5" >145.6%</td>
#       <td id="T_8fa6e_row1_col6" class="data row1 col6" >56.8%</td>
#       <td id="T_8fa6e_row1_col7" class="data row1 col7" >142.5%</td>
#       <td id="T_8fa6e_row1_col8" class="data row1 col8" >4.8%</td>
#       <td id="T_8fa6e_row1_col9" class="data row1 col9" >15.0%<

# %% [markdown]
# # Plot spread for all emission components of an individual vehicle class

# %%
vehicle_class = 'pass. car'
sns.boxplot(data = ef_grouped.loc[vehicle_class], x='rel_min', y='Component')
sns.boxplot(data = ef_grouped.loc[vehicle_class], x='rel_max', y='Component')

plt.axvline(0, color = 'black', linewidth = 0.5, linestyle = '--')
plt.xlabel('Relative difference from reference EF [%]')
# Out:
# Text(0.5, 0, 'Relative difference from reference EF [%]')

# %% [markdown]
# # Investigate the emission factor for the most prominent road categories in Munich

# %%
vehicle_category = 'pass. car'
component = 'CO2(rep)'
years = [2018, 2019, 2020]

_comb = pd.concat([ef_austria, ef_germany, ef_swiss])
comb = _comb[(_comb['VehCat'] == vehicle_category) & 
                   (_comb['Component'] == component) & 
                   (_comb['Year'].isin(years))]

# plotting
fig, ax = plt.subplots(2,2, figsize = (8,8), tight_layout = True)
loc = [0,0]

for cat in ['URB/Access/30', 'URB/Distr/50', 'URB/Trunk-City/60', 'URB/MW-Nat./120']:
    data = comb[comb['TrafficSit'].str.contains(cat)]
    
    sns.scatterplot(ax = ax[*loc], data=data, x = 'TrafficSit',
                    y = 'EFA_weighted', hue ='TrafficScenario')
    
    ax[*loc].get_legend().remove()
    labels = ax[*loc].get_xticklabels()
    labels_updated = [str(l).split('/')[3][:-2] for l in labels]
    ax[*loc].set_xticks(ax[*loc].get_xticks(), labels_updated,
                        rotation=45, ha='right')
    ax[*loc].set_title(' '.join(cat.split('/')[1:]))
   
   # increment axis
    loc[0]+=1
    if loc[0]>1:
        loc[0]=0
        loc[1]+=1

plt.subplots_adjust(hspace=0.4)
plt.xticks(rotation=45, ha='right')
plt.suptitle(component + '; ' + vehicle_category)

# prepare legend
handles, labels = plt.gca().get_legend_handles_labels()
updated_labels = ['Austria', 'Germany', 'Swiss']
by_label = dict(zip(updated_labels, handles))
fig.legend(by_label.values(),
           by_label.keys(),
           bbox_to_anchor=(1.1, 0.55))
